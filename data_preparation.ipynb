# %%
import pandas as pd
import numpy as np
import mysql.connector as connection

# %%
df1 = pd.read_csv("N:/my_projects/credit_card_financial_analysis/Datasets/cc_add.csv")
df1
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      31-12-2023  Week-53  Q4          2023
# 1                   96      31-12-2023  Week-53  Q4          2023
# ...

# %%
df2 = pd.read_csv("N:/my_projects/credit_card_financial_analysis/Datasets/credit_card.csv")
df2
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10103   827695683          Blue          340                   1
# 10104   827703258          Blue          395                   1
# 10105   827712108          Blue          125                   1
# 10106   827888433          Blue          410                   0
# 10107   827890758          Blue          100                   0
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                     87      01-01-2023   Week-1  Q1          2023
# ...

# %%
df3 = pd.read_csv("N:/my_projects/credit_card_financial_analysis/Datasets/cust_add.csv")
df3
# Out:
#      Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0     963607849            42      F                3      Uneducated
# 1     932954954            62      F                0     High School
# 2     961650885            47      F                3       Doctorate
# 3     917695309            49      M                5        Graduate
# 4     957309271            53      F                3        Graduate
# ..          ...           ...    ...              ...             ...
# 180   964474458            38      M                1     High School
# 181   962482385            44      F                1        Graduate
# 182   919695363            52      F                1        Graduate
# 183   931822111            36      M                2         Unknown
# 184   925168075            58      F                2        Graduate
#
#     Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
df4 = pd.read_csv("N:/my_projects/credit_card_financial_analysis/Datasets/customer.csv")
df4
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0       708082083            24      F                1      Uneducated
# 1       708083283            62      F                0         Unknown
# 2       708084558            32      F                1         Unknown
# 3       708085458            38      M                2      Uneducated
# 4       708086958            48      M                4        Graduate
# ...           ...           ...    ...              ...             ...
# 10103   827695683            44      M                3        Graduate
# 10104   827703258            48      M                3         Unknown
# 10105   827712108            47      M                4        Graduate
# 10106   827888433            42      F                3        Graduate
# 10107   827890758            47      M                4     High School
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
df1.isnull().sum()
# Out:
# Client_Num               0
# Card_Category            0
# Annual_Fees              0
# Activation_30_Days       0
# Customer_Acq_Cost        0
# Week_Start_Date          0
# Week_Num                 0
# Qtr                      0
# current_year             0
# Credit_Limit             0
# Total_Revolving_Bal      0
# Total_Trans_Amt          0
# Total_Trans_Ct           0
# Avg_Utilization_Ratio    0
# Use Chip                 0
# Exp Type                 0
# Interest_Earned          0
# Delinquent_Acc           0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Client_Num               0
# Card_Category            0
# Annual_Fees              0
# Activation_30_Days       0
# Customer_Acq_Cost        0
# Week_Start_Date          0
# Week_Num                 0
# Qtr                      0
# current_year             0
# Credit_Limit             0
# Total_Revolving_Bal      0
# Total_Trans_Amt          0
# Total_Trans_Vol          0
# Avg_Utilization_Ratio    0
# Use Chip                 0
# Exp Type                 0
# Interest_Earned          0
# Delinquent_Acc           0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Client_Num                 0
# Customer_Age               0
# Gender                     0
# Dependent_Count            0
# Education_Level            0
# Marital_Status             0
# state_cd                   0
# Zipcode                    0
# Car_Owner                  0
# House_Owner                0
# Personal_loan              0
# contact                    0
# Customer_Job               0
# Income                     0
# Cust_Satisfaction_Score    0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# Client_Num                 0
# Customer_Age               0
# Gender                     0
# Dependent_Count            0
# Education_Level            0
# Marital_Status             0
# state_cd                   0
# Zipcode                    0
# Car_Owner                  0
# House_Owner                0
# Personal_loan              0
# contact                    0
# Customer_Job               0
# Income                     0
# Cust_Satisfaction_Score    0
# dtype: int64

# %%
df1.dtypes
# Out:
# Client_Num                 int64
# Card_Category             object
# Annual_Fees                int64
# Activation_30_Days         int64
# Customer_Acq_Cost          int64
# Week_Start_Date           object
# Week_Num                  object
# Qtr                       object
# current_year               int64
# Credit_Limit             float64
# Total_Revolving_Bal        int64
# Total_Trans_Amt            int64
# Total_Trans_Ct             int64
# Avg_Utilization_Ratio    float64
# Use Chip                  object
# Exp Type                  object
# Interest_Earned          float64
# Delinquent_Acc             int64
# dtype: object

# %%
df1
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      31-12-2023  Week-53  Q4          2023
# 1                   96      31-12-2023  Week-53  Q4          2023
# ...

# %%
df1['Week_Start_Date']=pd.to_datetime(df1['Week_Start_Date'])
# Out:
# C:\Users\nikhi.NIKHILESH\AppData\Local\Temp\ipykernel_19652\2827142736.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['Week_Start_Date']=pd.to_datetime(df1['Week_Start_Date'])

# %%
df1
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      2023-12-31  Week-53  Q4          2023
# 1                   96      2023-12-31  Week-53  Q4          2023
# ...

# %%
df1.dtypes
# Out:
# Client_Num                        int64
# Card_Category                    object
# Annual_Fees                       int64
# Activation_30_Days                int64
# Customer_Acq_Cost                 int64
# Week_Start_Date          datetime64[ns]
# Week_Num                         object
# Qtr                              object
# current_year                      int64
# Credit_Limit                    float64
# Total_Revolving_Bal               int64
# Total_Trans_Amt                   int64
# Total_Trans_Ct                    int64
# Avg_Utilization_Ratio           float64
# Use Chip                         object
# Exp Type                         object
# Interest_Earned                 float64
# Delinquent_Acc                    int64
# dtype: object

# %%
df2
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10103   827695683          Blue          340                   1
# 10104   827703258          Blue          395                   1
# 10105   827712108          Blue          125                   1
# 10106   827888433          Blue          410                   0
# 10107   827890758          Blue          100                   0
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                     87      01-01-2023   Week-1  Q1          2023
# ...

# %%
df2['Week_Start_Date']=pd.to_datetime(df2['Week_Start_Date'], format="%d-%m-%Y")

# %%
df2
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10103   827695683          Blue          340                   1
# 10104   827703258          Blue          395                   1
# 10105   827712108          Blue          125                   1
# 10106   827888433          Blue          410                   0
# 10107   827890758          Blue          100                   0
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df3.dtypes
# Out:
# Client_Num                  int64
# Customer_Age                int64
# Gender                     object
# Dependent_Count             int64
# Education_Level            object
# Marital_Status             object
# state_cd                   object
# Zipcode                     int64
# Car_Owner                  object
# House_Owner                object
# Personal_loan              object
# contact                    object
# Customer_Job               object
# Income                      int64
# Cust_Satisfaction_Score     int64
# dtype: object

# %%
df3
# Out:
#      Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0     963607849            42      F                3      Uneducated
# 1     932954954            62      F                0     High School
# 2     961650885            47      F                3       Doctorate
# 3     917695309            49      M                5        Graduate
# 4     957309271            53      F                3        Graduate
# ..          ...           ...    ...              ...             ...
# 180   964474458            38      M                1     High School
# 181   962482385            44      F                1        Graduate
# 182   919695363            52      F                1        Graduate
# 183   931822111            36      M                2         Unknown
# 184   925168075            58      F                2        Graduate
#
#     Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
df4.dtypes
# Out:
# Client_Num                  int64
# Customer_Age                int64
# Gender                     object
# Dependent_Count             int64
# Education_Level            object
# Marital_Status             object
# state_cd                   object
# Zipcode                     int64
# Car_Owner                  object
# House_Owner                object
# Personal_loan              object
# contact                    object
# Customer_Job               object
# Income                      int64
# Cust_Satisfaction_Score     int64
# dtype: object

# %%
df4
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0       708082083            24      F                1      Uneducated
# 1       708083283            62      F                0         Unknown
# 2       708084558            32      F                1         Unknown
# 3       708085458            38      M                2      Uneducated
# 4       708086958            48      M                4        Graduate
# ...           ...           ...    ...              ...             ...
# 10103   827695683            44      M                3        Graduate
# 10104   827703258            48      M                3         Unknown
# 10105   827712108            47      M                4        Graduate
# 10106   827888433            42      F                3        Graduate
# 10107   827890758            47      M                4     High School
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
df2.columns
# Out:
# Index(['Client_Num', 'Card_Category', 'Annual_Fees', 'Activation_30_Days',
#        'Customer_Acq_Cost', 'Week_Start_Date', 'Week_Num', 'Qtr',
#        'current_year', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Total_Trans_Amt', 'Total_Trans_Vol', 'Avg_Utilization_Ratio',
#        'Use Chip', 'Exp Type', 'Interest_Earned', 'Delinquent_Acc'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Client_Num', 'Card_Category', 'Annual_Fees', 'Activation_30_Days',
#        'Customer_Acq_Cost', 'Week_Start_Date', 'Week_Num', 'Qtr',
#        'current_year', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Total_Trans_Amt', 'Total_Trans_Ct', 'Avg_Utilization_Ratio',
#        'Use Chip', 'Exp Type', 'Interest_Earned', 'Delinquent_Acc'],
#       dtype='object')

# %%
df1
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      2023-12-31  Week-53  Q4          2023
# 1                   96      2023-12-31  Week-53  Q4          2023
# ...

# %%
df2
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10103   827695683          Blue          340                   1
# 10104   827703258          Blue          395                   1
# 10105   827712108          Blue          125                   1
# 10106   827888433          Blue          410                   0
# 10107   827890758          Blue          100                   0
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df1.rename(columns={'Total_Trans_Ct': 'Total_Trans_Vol'}, inplace=True)

# %%
df1
# Out:
#      Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0     963607849          Blue          300                   1
# 1     932954954          Blue          175                   1
# 2     961650885          Blue          195                   0
# 3     917695309          Blue          495                   1
# 4     957309271          Blue          100                   0
# ..          ...           ...          ...                 ...
# 180   964474458          Blue          100                   0
# 181   962482385        Silver          100                   1
# 182   919695363          Blue          475                   1
# 183   931822111          Blue          275                   0
# 184   925168075          Blue          245                   1
#
#      Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                  108      2023-12-31  Week-53  Q4          2023
# 1                   96      2023-12-31  Week-53  Q4          2023
# ...

# %%
df2
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10103   827695683          Blue          340                   1
# 10104   827703258          Blue          395                   1
# 10105   827712108          Blue          125                   1
# 10106   827888433          Blue          410                   0
# 10107   827890758          Blue          100                   0
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
credit_card_df = pd.concat([df2,df1], ignore_index=True)
credit_card_df
# Out:
#        Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0       708082083          Blue          200                   0
# 1       708083283          Blue          445                   1
# 2       708084558          Blue          140                   0
# 3       708085458          Blue          250                   1
# 4       708086958          Blue          320                   1
# ...           ...           ...          ...                 ...
# 10288   964474458          Blue          100                   0
# 10289   962482385        Silver          100                   1
# 10290   919695363          Blue          475                   1
# 10291   931822111          Blue          275                   0
# 10292   925168075          Blue          245                   1
#
#        Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  \
# 0                     87      2023-01-01   Week-1  Q1          2023
# ...

# %%
df3.columns
# Out:
# Index(['Client_Num', 'Customer_Age', 'Gender', 'Dependent_Count',
#        'Education_Level', 'Marital_Status', 'state_cd', 'Zipcode', 'Car_Owner',
#        'House_Owner', 'Personal_loan', 'contact', 'Customer_Job', 'Income',
#        'Cust_Satisfaction_Score'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['Client_Num', 'Customer_Age', 'Gender', 'Dependent_Count',
#        'Education_Level', 'Marital_Status', 'state_cd', 'Zipcode', 'Car_Owner',
#        'House_Owner', 'Personal_loan', 'contact', 'Customer_Job', 'Income',
#        'Cust_Satisfaction_Score'],
#       dtype='object')

# %%
customers_df = pd.concat([df4,df3], ignore_index=True)
customers_df
# Out:
#        Client_Num  Customer_Age Gender  Dependent_Count Education_Level  \
# 0       708082083            24      F                1      Uneducated
# 1       708083283            62      F                0         Unknown
# 2       708084558            32      F                1         Unknown
# 3       708085458            38      M                2      Uneducated
# 4       708086958            48      M                4        Graduate
# ...           ...           ...    ...              ...             ...
# 10288   964474458            38      M                1     High School
# 10289   962482385            44      F                1        Graduate
# 10290   919695363            52      F                1        Graduate
# 10291   931822111            36      M                2         Unknown
# 10292   925168075            58      F                2        Graduate
#
#       Marital_Status state_cd  Zipcode Car_Owner House_Owner Personal_loan  \
# ...

# %%
credit_card_df.to_csv("final_credit_card.csv", index=False)

# %%
customers_df.to_csv("final_customers.csv", index=False)
